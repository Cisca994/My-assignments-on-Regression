# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import statsmodels.api as sm

import seaborn as sns
sns.set()

# %%
raw_data = pd.read_csv("Social Media Dummy Data HSS.csv")
data = raw_data.copy()

# %%
data
# Out:
#       TV PROMOTION BUDGET in millions      Radio  Social Media Influencer  \
# 0                                16.0   6.566231      2.907983       Mega
# 1                                13.0   9.237765      2.409567       Mega
# 2                                41.0  15.886446      2.913410       Mega
# 3                                83.0  30.020028      6.922304       Mega
# 4                                15.0   8.437408      1.405998      Micro
# ...                               ...        ...           ...        ...
# 4567                             26.0   4.472360      0.717090      Micro
# 4568                             71.0  20.610685      6.545573       Nano
# 4569                             44.0  19.800072      5.096192      Micro
# 4570                             71.0  17.534640      1.940873      Macro
# 4571                             42.0  15.966688      5.046548      Micro
#
#            Sales
# 0      54.732757
# 1      46.677897
# 2     150.177829
# ...

# %%
data.isnull().sum()
# Out:
# TV PROMOTION BUDGET in millions    10
# Radio                               4
# Social Media                        6
# Influencer                          0
# Sales                               6
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# TV PROMOTION BUDGET in millions    0
# Radio                              0
# Social Media                       0
# Influencer                         0
# Sales                              0
# dtype: int64

# %%
data.describe()
# Out:
#        TV PROMOTION BUDGET in millions        Radio  Social Media        Sales
# count                      4546.000000  4546.000000   4546.000000  4546.000000
# mean                         54.062912    18.157533      3.323473   192.413332
# std                          26.104942     9.663260      2.211254    93.019873
# min                          10.000000     0.000684      0.000031    31.199409
# 25%                          32.000000    10.555355      1.530822   112.434612
# 50%                          53.000000    17.859513      3.055565   188.963678
# 75%                          77.000000    25.640603      4.804919   272.324236
# max                         100.000000    48.871161     13.981662   364.079751

# %%
x1 = data[["TV PROMOTION BUDGET in millions","Radio","Social Media"]]
y = data["Sales"]

# %%
x = sm.add_constant(x1)
x.head()
# Out:
#    const  TV PROMOTION BUDGET in millions      Radio  Social Media
# 0    1.0                             16.0   6.566231      2.907983
# 1    1.0                             13.0   9.237765      2.409567
# 2    1.0                             41.0  15.886446      2.913410
# 3    1.0                             83.0  30.020028      6.922304
# 4    1.0                             15.0   8.437408      1.405998

# %%
model = sm.OLS(y,x).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 1.505e+06
# Date:                Wed, 05 Jun 2024   Prob (F-statistic):               0.00
# Time:                        20:15:23   Log-Likelihood:                -11366.
# No. Observations:                4546   AIC:                         2.274e+04
# Df Residuals:                    4542   BIC:                         2.277e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
y_cap = model.params[0]  + (model.params[1] * 16.0) + (model.params[2] * 6.566231) + (model.params[3] * 2.907983)
y_cap
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3704\2298095230.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_cap = model.params[0]  + (model.params[1] * 16.0) + (model.params[2] * 6.566231) + (model.params[3] * 2.907983)
# 56.85551578590356

# %%
model.predict()
# Out:
# array([ 56.85551579,  46.15472574, 145.88277855, ..., 156.56578419,
#        252.7484957 , 149.45561852])
